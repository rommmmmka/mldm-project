# %%
import os

import mne

# %%
CHANNELS = {
    "F3-A2": "F3",
    "C3-A2": "C3",
    "O1-A2": "O1",
    "F4-A1": "F4",
    "C4-A1": "C4",
    "O2-A1": "O2",
}
RECORDING = 1

# %%
for recording in range(1, 11):
    print(f"====={recording}=====")
    raw_edf: mne.io.Raw = mne.io.read_raw_edf(
        f"isruc_s3/{recording}/{recording}.edf",
        preload=True,
        include=list(CHANNELS.keys())
    )
    raw_edf.rename_channels(CHANNELS)
    raw_edf.set_montage("standard_1020")

    with open(f"isruc_s3/{recording}/{recording}_1.txt", mode="r", encoding="utf-8") as file:
        annotator_1 = list(
            map(int, file.read().strip().split("\n"))
        )
    with open(f"isruc_s3/{recording}/{recording}_2.txt", mode="r", encoding="utf-8") as file:
        annotator_2 = list(
            map(int, file.read().strip().split("\n"))
        )

    annotations_onsets = {"separate": [], "combined": []}
    annotations_descriptions = {"annotator_1": [], "annotator_2": [], "combined": []}

    for i, (stage_1, stage_2) in enumerate(zip(annotator_1, annotator_2)):
        annotations_onsets["separate"].append(i * 30)
        annotations_descriptions["annotator_1"].append(stage_1)
        annotations_descriptions["annotator_2"].append(stage_2)

        if stage_1 != stage_2:
            continue
        annotations_onsets["combined"].append(i * 30)
        annotations_descriptions["combined"].append(stage_1)

    annotated_recordings = {
        "annotator_1": raw_edf.copy().set_annotations(
            mne.Annotations(
                onset=annotations_onsets["separate"],
                duration=30,
                description=annotations_descriptions["annotator_1"]
            )
        ),
        "annotator_2": raw_edf.copy().set_annotations(
            mne.Annotations(
                onset=annotations_onsets["separate"],
                duration=30,
                description=annotations_descriptions["annotator_2"]
            )
        ),
        "combined": raw_edf.copy().set_annotations(
            mne.Annotations(
                onset=annotations_onsets["combined"],
                duration=30,
                description=annotations_descriptions["combined"]
            )
        )
    }

    for annotator_type, annotated_edf in annotated_recordings.items():
        if not os.path.exists(f"processed/{recording}"):
            os.makedirs(f"processed/{recording}")
        annotated_edf.save(f"processed/{recording}/{recording}_{annotator_type}_eeg.fif", overwrite=True)
# Out:
# =====1=====
# Extracting EDF parameters from C:\Users\Raman\PycharmProjects\mldm-project\isruc_s3\1\1.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5723999  =      0.000 ... 28619.995 secs...
# Overwriting existing file.
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\1\1_annotator_1_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\1\1_annotator_1_eeg.fif
# [done]
# Overwriting existing file.
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\1\1_annotator_2_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\1\1_annotator_2_eeg.fif
# [done]
# Overwriting existing file.
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\1\1_combined_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\1\1_combined_eeg.fif
# [done]
# =====2=====
# Extracting EDF parameters from C:\Users\Raman\PycharmProjects\mldm-project\isruc_s3\2\2.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5645999  =      0.000 ... 28229.995 secs...
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\2\2_annotator_1_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\2\2_annotator_1_eeg.fif
# [done]
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\2\2_annotator_2_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\2\2_annotator_2_eeg.fif
# [done]
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\2\2_combined_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\2\2_combined_eeg.fif
# [done]
# =====3=====
# Extracting EDF parameters from C:\Users\Raman\PycharmProjects\mldm-project\isruc_s3\3\3.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4943999  =      0.000 ... 24719.995 secs...
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\3\3_annotator_1_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\3\3_annotator_1_eeg.fif
# [done]
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\3\3_annotator_2_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\3\3_annotator_2_eeg.fif
# [done]
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\3\3_combined_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\3\3_combined_eeg.fif
# [done]
# =====4=====
# Extracting EDF parameters from C:\Users\Raman\PycharmProjects\mldm-project\isruc_s3\4\4.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4763999  =      0.000 ... 23819.995 secs...
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\4\4_annotator_1_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\4\4_annotator_1_eeg.fif
# [done]
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\4\4_annotator_2_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\4\4_annotator_2_eeg.fif
# [done]
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\4\4_combined_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\4\4_combined_eeg.fif
# [done]
# =====5=====
# Extracting EDF parameters from C:\Users\Raman\PycharmProjects\mldm-project\isruc_s3\5\5.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5663999  =      0.000 ... 28319.995 secs...
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\5\5_annotator_1_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\5\5_annotator_1_eeg.fif
# [done]
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\5\5_annotator_2_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\5\5_annotator_2_eeg.fif
# [done]
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\5\5_combined_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\5\5_combined_eeg.fif
# [done]
# =====6=====
# Extracting EDF parameters from C:\Users\Raman\PycharmProjects\mldm-project\isruc_s3\6\6.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5117999  =      0.000 ... 25589.995 secs...
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\6\6_annotator_1_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\6\6_annotator_1_eeg.fif
# [done]
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\6\6_annotator_2_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\6\6_annotator_2_eeg.fif
# [done]
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\6\6_combined_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\6\6_combined_eeg.fif
# [done]
# =====7=====
# Extracting EDF parameters from C:\Users\Raman\PycharmProjects\mldm-project\isruc_s3\7\7.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4883999  =      0.000 ... 24419.995 secs...
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\7\7_annotator_1_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\7\7_annotator_1_eeg.fif
# [done]
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\7\7_annotator_2_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\7\7_annotator_2_eeg.fif
# [done]
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\7\7_combined_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\7\7_combined_eeg.fif
# [done]
# =====8=====
# Extracting EDF parameters from C:\Users\Raman\PycharmProjects\mldm-project\isruc_s3\8\8.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5999999  =      0.000 ... 29999.995 secs...
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\8\8_annotator_1_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\8\8_annotator_1_eeg.fif
# [done]
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\8\8_annotator_2_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\8\8_annotator_2_eeg.fif
# [done]
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\8\8_combined_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\8\8_combined_eeg.fif
# [done]
# =====9=====
# Extracting EDF parameters from C:\Users\Raman\PycharmProjects\mldm-project\isruc_s3\9\9.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5813999  =      0.000 ... 29069.995 secs...
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\9\9_annotator_1_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\9\9_annotator_1_eeg.fif
# [done]
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\9\9_annotator_2_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\9\9_annotator_2_eeg.fif
# [done]
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\9\9_combined_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\9\9_combined_eeg.fif
# [done]
# =====10=====
# Extracting EDF parameters from C:\Users\Raman\PycharmProjects\mldm-project\isruc_s3\10\10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 4775999  =      0.000 ... 23879.995 secs...
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\10\10_annotator_1_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\10\10_annotator_1_eeg.fif
# [done]
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\10\10_annotator_2_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\10\10_annotator_2_eeg.fif
# [done]
# Writing C:\Users\Raman\PycharmProjects\mldm-project\processed\10\10_combined_eeg.fif
# Closing C:\Users\Raman\PycharmProjects\mldm-project\processed\10\10_combined_eeg.fif
# [done]
